# %% [markdown]
# <a href="https://colab.research.google.com/github/SzymonNowakowski/Machine-Learning-2024/blob/master/Lab10-convolutional-neural-network-CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 10 - Convolutional Neural Network, CNN
#
# ### Author: Szymon Nowakowski

# %% [markdown]
# # Presentation on Convolutional Layers
# --------------------
#
# We shall start off by going through a [short presentation on convolusional layers](https://github.com/SzymonNowakowski/Machine-Learning-2024/blob/master/convolutional_layers.pdf). It is best to first download it and then go through it in a slide-show layout.

# %% [markdown]
# # Reading MNIST Dataset
# ----------------------------------

# %%
import torch
import torchvision
from matplotlib import pyplot

transform = torchvision.transforms.Compose(
    [ torchvision.transforms.ToTensor(), #Converts a PIL Image or numpy.ndarray (H x W x C) in the range [0, 255] to a torch.FloatTensor of shape (C x H x W) in the range [0.0, 1.0]
      torchvision.transforms.Normalize((0.1307), (0.3081))])

trainset = torchvision.datasets.MNIST(root='./data',
                                      train=True,
                                      download=True,
                                      transform=transform)

trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=2048,
                                          shuffle=True)   #we do shuffle it to give more randomizations to training epochs

testset = torchvision.datasets.MNIST(root='./data',
                                     train=False,
                                     download=True,
                                     transform=transform)

testloader = torch.utils.data.DataLoader(testset,
                                         batch_size=1,
                                         shuffle=False)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %% [markdown]
# # Tensor Sizes
# -------------------
#
# Recall:
# - Batched labels are of order one. The first (and only) index is a sample index within a batch.
# - Image batches have order 4. The first order is a batch order, but a second order has dimensionality of 1 and thus it can be indexed by 0 only.
#   - This index represents a Channel number inserted here by `ToTensor()` transformation, always 0.
#   - This singleton order should be retained because we want to use convolutional layers, which explicitly require this order. For RGB images we have 3 channels, for B&W images we have only one channel.

# %% [markdown]
# # CNN Definition
# -----------------

# %% [markdown]
# ## Task
#
# Your job now is to code the definition of the LeNet5 neural network. You can find the definition [here](https://en.wikipedia.org/wiki/LeNet#/media/File:Comparison_image_neural_networks.svg).

# %%
import torch.nn as nn
import torch.nn.functional as F

class LeNet5(torch.nn.Module):
    def __init__(self):
        super().__init__()

        # TODO: add missing layers
        self.conv1 = torch.nn.Conv2d(in_channels = 1, out_channels = 6, padding = 2, kernel_size = 5, padding_mode = "replicate") #mamy czarno biały obraz
        self.avgpool = torch.nn.AvgPool2d(kernel_size = 2, stride = 2)
        self.relu = torch.nn.ReLU()
        self.conv2 = torch.nn.Conv2d(in_channels = 6, out_channels = 16, kernel_size = 5)
        self.conv3 = torch.nn.Conv2d(in_channels = 16, out_channels = 120, kernel_size = 5)

        self.linear1 = torch.nn.Linear(120, 84)
        self.linear2 = torch.nn.Linear(84, 10)

        self.dropout = torch.nn.Dropout(0.05)

    def forward(self, x):               # B, 1, 28, 28

        # TODO: add missing processing
        x = self.relu(self.conv1(x))    # B, 6, 28, 28
        x = self.avgpool(x)             # B, 16, 14, 14
        x = self.relu(self.conv2(x))    # B, 16, 10, 10
        x = self.avgpool(x)             # B, 16, 5, 5
        x = self.relu(self.conv3(x))    # B, 120, 1, 1
        x = x.squeeze(-1).squeeze(-1)   # B, 120, 1 ->  B, 120
        x = self.relu(self.linear1(x))  # B, 84
        x = self.linear2(x)             # B, 10            
        x = self.dropout(x)
        return x

# %% [markdown]
# # Training Loop
# ----------------------

# %%
# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Working on {device}")

net = LeNet5().to(device)
optimizer = torch.optim.Adam(net.parameters(), 0.001)   #initial and fixed learning rate of 0.001.

net.train()    #it notifies the network layers (especially batchnorm or dropout layers, which we don't use in this example) that we are doing traning
for epoch in range(16):  #  an epoch is a training run through the whole data set

    for batch, data in enumerate(trainloader):
        batch_inputs, batch_labels = data

        batch_inputs = batch_inputs.to(device)  #explicitly moving the data to the target device
        batch_labels = batch_labels.to(device)

        optimizer.zero_grad()

        batch_outputs = net(batch_inputs)   #this line calls the forward(self, x) method of the LeNet5 object. Please note,
                                            # the nonlinear activation after the last layer is NOT applied
        loss = torch.nn.functional.cross_entropy(batch_outputs, batch_labels, reduction = "mean") #instead, nonlinear softmax is applied internally in THIS loss function
        print("epoch:", epoch, "batch:", batch, "current batch loss:", loss.item())
        loss.backward()       #this computes gradients as we have seen in previous workshops
        optimizer.step()     #but this line in fact updates our neural network.
                                ####You can experiment - comment this line and check, that the loss DOE
# Out:
# Working on cuda
# epoch: 0 batch: 0 current batch loss: 2.3036482334136963
# epoch: 0 batch: 1 current batch loss: 2.2966179847717285
# epoch: 0 batch: 2 current batch loss: 2.2920055389404297
# epoch: 0 batch: 3 current batch loss: 2.2825686931610107
# epoch: 0 batch: 4 current batch loss: 2.277055263519287
# epoch: 0 batch: 5 current batch loss: 2.264756679534912
# epoch: 0 batch: 6 current batch loss: 2.252285957336426
# epoch: 0 batch: 7 current batch loss: 2.2309796810150146
# epoch: 0 batch: 8 current batch loss: 2.212344169616699
# epoch: 0 batch: 9 current batch loss: 2.1868245601654053
# epoch: 0 batch: 10 current batch loss: 2.155872344970703
# epoch: 0 batch: 11 current batch loss: 2.1191115379333496
# epoch: 0 batch: 12 current batch loss: 2.075472354888916
# epoch: 0 batch: 13 current batch loss: 2.0305681228637695
# epoch: 0 batch: 14 current batch loss: 1.9715903997421265
# epoch: 0 batch: 15 current batch loss: 1.9053173065185547
# epoch: 0 batch: 16 current batch loss: 1.8439255952835083
# epoch: 0 batch: 17 current batch loss: 1.768882393836975
# epoch: 0 batch: 18 current batch loss: 1.681076169013977
# epoch: 0 batch: 19 current batch loss: 1.5817313194274902
# epoch: 0 batch: 20 current batch loss: 1.512281894683838
# epoch: 0 batch: 21 current batch loss: 1.424829363822937
# epoch: 0 batch: 22 current batch loss: 1.3450803756713867
# epoch: 0 batch: 23 current batch loss: 1.2556465864181519
# epoch: 0 batch: 24 current batch loss: 1.1711176633834839
# epoch: 0 batch: 25 current batch loss: 1.1442768573760986
# epoch: 0 batch: 26 current batch loss: 1.0491745471954346
# epoch: 0 batch: 27 current batch loss: 0.9894517064094543
# epoch: 0 batch: 28 current batch loss: 0.9794273972511292
# epoch: 0 batch: 29 current batch loss: 0.8897046446800232
# epoch: 1 batch: 0 current batch loss: 0.8596163392066956
# epoch: 1 batch: 1 current batch loss: 0.8241510987281799
# epoch: 1 batch: 2 current batch loss: 0.7719170451164246
# epoch: 1 batch: 3 current batch loss: 0.717583417892456
# epoch: 1 batch: 4 current batch loss: 0.725056529045105
# epoch: 1 batch: 5 current batch loss: 0.6928607821464539
# epoch: 1 batch: 6 current batch loss: 0.6620085835456848
# epoch: 1 batch: 7 current batch loss: 0.6719508767127991
# epoch: 1 batch: 8 current batch loss: 0.639078676700592
# epoch: 1 batch: 9 current batch loss: 0.6129993796348572
# epoch: 1 batch: 10 current batch loss: 0.63991779088974
# epoch: 1 batch: 11 current batch loss: 0.577862024307251
# epoch: 1 batch: 12 current batch loss: 0.5721204876899719
# epoch: 1 batch: 13 current batch loss: 0.5869905948638916
# epoch: 1 batch: 14 current batch loss: 0.5630444288253784
# epoch: 1 batch: 15 current batch loss: 0.5701945424079895
# epoch: 1 batch: 16 current batch loss: 0.5538573265075684
# epoch: 1 batch: 17 current batch loss: 0.5158838629722595
# epoch: 1 batch: 18 current batch loss: 0.49114182591438293
# epoch: 1 batch: 19 current batch loss: 0.5085622072219849
# epoch: 1 batch: 20 current batch loss: 0.47071677446365356
# epoch: 1 batch: 21 current batch loss: 0.49266475439071655
# epoch: 1 batch: 22 current batch loss: 0.4730362296104431
# epoch: 1 batch: 23 current batch loss: 0.49175211787223816
# epoch: 1 batch: 24 current batch loss: 0.47171100974082947
# epoch: 1 batch: 25 current batch loss: 0.489208847284317
# epoch: 1 batch: 26 current batch loss: 0.4465203881263733
# epoch: 1 batch: 27 current batch loss: 0.4414294362068176
# epoch: 1 batch: 28 current batch loss: 0.3944355249404907
# epoch: 1 batch: 29 current batch loss: 0.42401957511901855
# epoch: 2 batch: 0 current batch loss: 0.4482526183128357
# epoch: 2 batch: 1 current batch loss: 0.4045340418815613
# epoch: 2 batch: 2 current batch loss: 0.42019185423851013
# epoch: 2 batch: 3 current batch loss: 0.4307498037815094
# epoch: 2 batch: 4 current batch loss: 0.41734760999679565
# epoch: 2 batch: 5 current batch loss: 0.44018301367759705
# epoch: 2 batch: 6 current batch loss: 0.4042154550552368
# epoch: 2 batch: 7 current batch loss: 0.39879360795021057
# epoch: 2 batch: 8 current batch loss: 0.39803189039230347
# epoch: 2 batch: 9 current batch loss: 0.40262916684150696
# epoch: 2 batch: 10 current batch loss: 0.37644463777542114
# epoch: 2 batch: 11 current batch loss: 0.3709419071674347
# epoch: 2 batch: 12 current batch loss: 0.36197036504745483
# epoch: 2 batch: 13 current batch loss: 0.3327772319316864
# epoch: 2 batch: 14 current batch loss: 0.3363708257675171
# epoch: 2 batch: 15 current batch loss: 0.3524286448955536
# epoch: 2 batch: 16 current batch loss: 0.3602539598941803
# epoch: 2 batch: 17 current batch loss: 0.31280946731567383
# epoch: 2 batch: 18 current batch loss: 0.33960700035095215
# epoch: 2 batch: 19 current batch loss: 0.3453947603702545
# epoch: 2 batch: 20 current batch loss: 0.3441866934299469
# epoch: 2 batch: 21 current batch loss: 0.3354465663433075
# epoch: 2 batch: 22 current batch loss: 0.30833151936531067
# epoch: 2 batch: 23 current batch loss: 0.3449993133544922
# epoch: 2 batch: 24 current batch loss: 0.3387485146522522
# epoch: 2 batch: 25 current batch loss: 0.3031860291957855
# epoch: 2 batch: 26 current batch loss: 0.31638410687446594
# epoch: 2 batch: 27 current batch loss: 0.31905487179756165
# epoch: 2 batch: 28 current batch loss: 0.3094955086708069
# epoch: 2 batch: 29 current batch loss: 0.29620012640953064
# epoch: 3 batch: 0 current batch loss: 0.3017999231815338
# epoch: 3 batch: 1 current batch loss: 0.2982126474380493
# epoch: 3 batch: 2 current batch loss: 0.28153306245803833
# epoch: 3 batch: 3 current batch loss: 0.3115963041782379
# epoch: 3 batch: 4 current batch loss: 0.2828028202056885
# epoch: 3 batch: 5 current batch loss: 0.29674986004829407
# epoch: 3 batch: 6 current batch loss: 0.285752534866333
# epoch: 3 batch: 7 current batch loss: 0.2713378369808197
# epoch: 3 batch: 8 current batch loss: 0.29546844959259033
# epoch: 3 batch: 9 current batch loss: 0.29170435667037964
# epoch: 3 batch: 10 current batch loss: 0.3014770746231079
# epoch: 3 batch: 11 current batch loss: 0.29096168279647827
# epoch: 3 batch: 12 current batch loss: 0.2666192352771759
# epoch: 3 batch: 13 current batch loss: 0.26614058017730713
# epoch: 3 batch: 14 current batch loss: 0.27543917298316956
# epoch: 3 batch: 15 current batch loss: 0.26462674140930176
# epoch: 3 batch: 16 current batch loss: 0.2762184739112854
# epoch: 3 batch: 17 current batch loss: 0.26468008756637573
# epoch: 3 batch: 18 current batch loss: 0.26836371421813965
# epoch: 3 batch: 19 current batch loss: 0.24609339237213135
# epoch: 3 batch: 20 current batch loss: 0.270397424697876
# epoch: 3 batch: 21 current batch loss: 0.2427653819322586
# epoch: 3 batch: 22 current batch loss: 0.26748961210250854
# epoch: 3 batch: 23 current batch loss: 0.26074740290641785
# epoch: 3 batch: 24 current batch loss: 0.2706504762172699
# epoch: 3 batch: 25 current batch loss: 0.2474796175956726
# epoch: 3 batch: 26 current batch loss: 0.24596890807151794
# epoch: 3 batch: 27 current batch loss: 0.2662852108478546
# epoch: 3 batch: 28 current batch loss: 0.24955041706562042
# epoch: 3 batch: 29 current batch loss: 0.2532006502151489
# epoch: 4 batch: 0 current batch loss: 0.27037379145622253
# epoch: 4 batch: 1 current batch loss: 0.26033568382263184
# epoch: 4 batch: 2 current batch loss: 0.23420540988445282
# epoch: 4 batch: 3 current batch loss: 0.250879168510437
# epoch: 4 batch: 4 current batch loss: 0.21673794090747833
# epoch: 4 batch: 5 current batch loss: 0.23010236024856567
# epoch: 4 batch: 6 current batch loss: 0.2638932764530182
# epoch: 4 batch: 7 current batch loss: 0.262785404920578
# epoch: 4 batch: 8 current batch loss: 0.24885068833827972
# epoch: 4 batch: 9 current batch loss: 0.24375735223293304
# epoch: 4 batch: 10 current batch loss: 0.2303411066532135
# epoch: 4 batch: 11 current batch loss: 0.21989348530769348
# epoch: 4 batch: 12 current batch loss: 0.23409533500671387
# epoch: 4 batch: 13 current batch loss: 0.23434075713157654
# epoch: 4 batch: 14 current batch loss: 0.21606309711933136
# epoch: 4 batch: 15 current batch loss: 0.22821515798568726
# epoch: 4 batch: 16 current batch loss: 0.2063869684934616
# epoch: 4 batch: 17 current batch loss: 0.2109767496585846
# epoch: 4 batch: 18 current batch loss: 0.22654573619365692
# epoch: 4 batch: 19 current batch loss: 0.22040097415447235
# epoch: 4 batch: 20 current batch loss: 0.19603003561496735
# epoch: 4 batch: 21 current batch loss: 0.2069360911846161
# epoch: 4 batch: 22 current batch loss: 0.23944418132305145
# epoch: 4 batch: 23 current batch loss: 0.21028874814510345
# epoch: 4 batch: 24 current batch loss: 0.20258960127830505
# epoch: 4 batch: 25 current batch loss: 0.2212454229593277
# epoch: 4 batch: 26 current batch loss: 0.20588384568691254
# epoch: 4 batch: 27 current batch loss: 0.20769962668418884
# epoch: 4 batch: 28 current batch loss: 0.21620608866214752
# epoch: 4 batch: 29 current batch loss: 0.16928209364414215
# epoch: 5 batch: 0 current batch loss: 0.2203112691640854
# epoch: 5 batch: 1 current batch loss: 0.21319988369941711
# epoch: 5 batch: 2 current batch loss: 0.19353491067886353
# epoch: 5 batch: 3 current batch loss: 0.19368848204612732
# epoch: 5 batch: 4 current batch loss: 0.1729113757610321
# epoch: 5 batch: 5 current batch loss: 0.20369663834571838
# epoch: 5 batch: 6 current batch loss: 0.18185871839523315
# epoch: 5 batch: 7 current batch loss: 0.20568090677261353
# epoch: 5 batch: 8 current batch loss: 0.18380887806415558
# epoch: 5 batch: 9 current batch loss: 0.19904553890228271
# epoch: 5 batch: 10 current batch loss: 0.23492193222045898
# epoch: 5 batch: 11 current batch loss: 0.18586258590221405
# epoch: 5 batch: 12 current batch loss: 0.20641577243804932
# epoch: 5 batch: 13 current batch loss: 0.21199902892112732
# epoch: 5 batch: 14 current batch loss: 0.1791507750749588
# epoch: 5 batch: 15 current batch loss: 0.18470917642116547
# epoch: 5 batch: 16 current batch loss: 0.2259063422679901
# epoch: 5 batch: 17 current batch loss: 0.2219357043504715
# epoch: 5 batch: 18 current batch loss: 0.19064441323280334
# epoch: 5 batch: 19 current batch loss: 0.22180849313735962
# epoch: 5 batch: 20 current batch loss: 0.20144778490066528
# epoch: 5 batch: 21 current batch loss: 0.17537356913089752
# epoch: 5 batch: 22 current batch loss: 0.18935175240039825
# epoch: 5 batch: 23 current batch loss: 0.17708447575569153
# epoch: 5 batch: 24 current batch loss: 0.19466139376163483
# epoch: 5 batch: 25 current batch loss: 0.19206808507442474
# epoch: 5 batch: 26 current batch loss: 0.19046460092067719
# epoch: 5 batch: 27 current batch loss: 0.18648986518383026
# epoch: 5 batch: 28 current batch loss: 0.17478737235069275
# epoch: 5 batch: 29 current batch loss: 0.18381352722644806
# epoch: 6 batch: 0 current batch loss: 0.18064336478710175
# epoch: 6 batch: 1 current batch loss: 0.17893671989440918
# epoch: 6 batch: 2 current batch loss: 0.19152507185935974
# epoch: 6 batch: 3 current batch loss: 0.17559361457824707
# epoch: 6 batch: 4 current batch loss: 0.17843559384346008
# epoch: 6 batch: 5 current batch loss: 0.17573599517345428
# epoch: 6 batch: 6 current batch loss: 0.19446413218975067
# epoch: 6 batch: 7 current batch loss: 0.18770626187324524
# epoch: 6 batch: 8 current batch loss: 0.19978705048561096
# epoch: 6 batch: 9 current batch loss: 0.1700306087732315
# epoch: 6 batch: 10 current batch loss: 0.186362162232399
# epoch: 6 batch: 11 current batch loss: 0.17108574509620667
# epoch: 6 batch: 12 current batch loss: 0.17880941927433014
# epoch: 6 batch: 13 current batch loss: 0.17588189244270325
# epoch: 6 batch: 14 current batch loss: 0.18988315761089325
# epoch: 6 batch: 15 current batch loss: 0.173422709107399
# epoch: 6 batch: 16 current batch loss: 0.19285617768764496
# epoch: 6 batch: 17 current batch loss: 0.18310502171516418
# epoch: 6 batch: 18 current batch loss: 0.18397198617458344
# epoch: 6 batch: 19 current batch loss: 0.15964891016483307
# epoch: 6 batch: 20 current batch loss: 0.1818121373653412
# epoch: 6 batch: 21 current batch loss: 0.1757047474384308
# epoch: 6 batch: 22 current batch loss: 0.1743404120206833
# epoch: 6 batch: 23 current batch loss: 0.1533351093530655
# epoch: 6 batch: 24 current batch loss: 0.17834554612636566
# epoch: 6 batch: 25 current batch loss: 0.16345123946666718
# epoch: 6 batch: 26 current batch loss: 0.14487870037555695
# epoch: 6 batch: 27 current batch loss: 0.14560411870479584
# epoch: 6 batch: 28 current batch loss: 0.16685843467712402
# epoch: 6 batch: 29 current batch loss: 0.1720554232597351
# epoch: 7 batch: 0 current batch loss: 0.1581902951002121
# epoch: 7 batch: 1 current batch loss: 0.1520843356847763
# epoch: 7 batch: 2 current batch loss: 0.1535436362028122
# epoch: 7 batch: 3 current batch loss: 0.15984497964382172
# epoch: 7 batch: 4 current batch loss: 0.14385385811328888
# epoch: 7 batch: 5 current batch loss: 0.15647023916244507
# epoch: 7 batch: 6 current batch loss: 0.18174761533737183
# epoch: 7 batch: 7 current batch loss: 0.16975894570350647
# epoch: 7 batch: 8 current batch loss: 0.1410648077726364
# epoch: 7 batch: 9 current batch loss: 0.15420550107955933
# epoch: 7 batch: 10 current batch loss: 0.18280145525932312
# epoch: 7 batch: 11 current batch loss: 0.15014217793941498
# epoch: 7 batch: 12 current batch loss: 0.17606869339942932
# epoch: 7 batch: 13 current batch loss: 0.2054510861635208
# epoch: 7 batch: 14 current batch loss: 0.16159328818321228
# epoch: 7 batch: 15 current batch loss: 0.17014984786510468
# epoch: 7 batch: 16 current batch loss: 0.182414710521698
# epoch: 7 batch: 17 current batch loss: 0.18833503127098083
# epoch: 7 batch: 18 current batch loss: 0.16993172466754913
# epoch: 7 batch: 19 current batch loss: 0.15433736145496368
# epoch: 7 batch: 20 current batch loss: 0.17399819195270538
# epoch: 7 batch: 21 current batch loss: 0.1712743639945984
# epoch: 7 batch: 22 current batch loss: 0.1394573152065277
# epoch: 7 batch: 23 current batch loss: 0.17150986194610596
# epoch: 7 batch: 24 current batch loss: 0.1443096101284027
# epoch: 7 batch: 25 current batch loss: 0.16575537621974945
# epoch: 7 batch: 26 current batch loss: 0.1694817841053009
# epoch: 7 batch: 27 current batch loss: 0.15315242111682892
# epoch: 7 batch: 28 current batch loss: 0.19706454873085022
# epoch: 7 batch: 29 current batch loss: 0.1317158043384552
# epoch: 8 batch: 0 current batch loss: 0.15746794641017914
# epoch: 8 batch: 1 current batch loss: 0.16375653445720673
# epoch: 8 batch: 2 current batch loss: 0.15899986028671265
# epoch: 8 batch: 3 current batch loss: 0.179245725274086
# epoch: 8 batch: 4 current batch loss: 0.15258601307868958
# epoch: 8 batch: 5 current batch loss: 0.13799084722995758
# epoch: 8 batch: 6 current batch loss: 0.16191503405570984
# epoch: 8 batch: 7 current batch loss: 0.14773589372634888
# epoch: 8 batch: 8 current batch loss: 0.140165776014328
# epoch: 8 batch: 9 current batch loss: 0.15639828145503998
# epoch: 8 batch: 10 current batch loss: 0.14742988348007202
# epoch: 8 batch: 11 current batch loss: 0.1782594621181488
# epoch: 8 batch: 12 current batch loss: 0.1455078274011612
# epoch: 8 batch: 13 current batch loss: 0.15321922302246094
# epoch: 8 batch: 14 current batch loss: 0.1370846927165985
# epoch: 8 batch: 15 current batch loss: 0.1673189401626587
# epoch: 8 batch: 16 current batch loss: 0.15258197486400604
# epoch: 8 batch: 17 current batch loss: 0.1633177250623703
# epoch: 8 batch: 18 current batch loss: 0.15851841866970062
# epoch: 8 batch: 19 current batch loss: 0.1592046320438385
# epoch: 8 batch: 20 current batch loss: 0.16664673388004303
# epoch: 8 batch: 21 current batch loss: 0.13496579229831696
# epoch: 8 batch: 22 current batch loss: 0.1497575342655182
# epoch: 8 batch: 23 current batch loss: 0.14692510664463043
# epoch: 8 batch: 24 current batch loss: 0.1514595001935959
# epoch: 8 batch: 25 current batch loss: 0.13832077383995056
# epoch: 8 batch: 26 current batch loss: 0.13214394450187683
# epoch: 8 batch: 27 current batch loss: 0.12674197554588318
# epoch: 8 batch: 28 current batch loss: 0.14721961319446564
# epoch: 8 batch: 29 current batch loss: 0.1214870885014534
# epoch: 9 batch: 0 current batch loss: 0.14200764894485474
# epoch: 9 batch: 1 current batch loss: 0.15770940482616425
# epoch: 9 batch: 2 current batch loss: 0.13082729279994965
# epoch: 9 batch: 3 current batch loss: 0.1489219069480896
# epoch: 9 batch: 4 current batch loss: 0.12239183485507965
# epoch: 9 batch: 5 current batch loss: 0.1450739949941635
# epoch: 9 batch: 6 current batch loss: 0.14227528870105743
# epoch: 9 batch: 7 current batch loss: 0.14023680984973907
# epoch: 9 batch: 8 current batch loss: 0.14210589230060577
# epoch: 9 batch: 9 current batch loss: 0.1461002677679062
# epoch: 9 batch: 10 current batch loss: 0.13991069793701172
# epoch: 9 batch: 11 current batch loss: 0.12483447045087814
# epoch: 9 batch: 12 current batch loss: 0.15048688650131226
# epoch: 9 batch: 13 current batch loss: 0.1525338590145111
# epoch: 9 batch: 14 current batch loss: 0.14298558235168457
# epoch: 9 batch: 15 current batch loss: 0.13856272399425507
# epoch: 9 batch: 16 current batch loss: 0.12744957208633423
# epoch: 9 batch: 17 current batch loss: 0.13502761721611023
# epoch: 9 batch: 18 current batch loss: 0.13829416036605835
# epoch: 9 batch: 19 current batch loss: 0.14848046004772186
# epoch: 9 batch: 20 current batch loss: 0.15688607096672058
# epoch: 9 batch: 21 current batch loss: 0.11439628154039383
# epoch: 9 batch: 22 current batch loss: 0.1327657699584961
# epoch: 9 batch: 23 current batch loss: 0.13240361213684082
# epoch: 9 batch: 24 current batch loss: 0.14893057942390442
# epoch: 9 batch: 25 current batch loss: 0.12289939820766449
# epoch: 9 batch: 26 current batch loss: 0.14697019755840302
# epoch: 9 batch: 27 current batch loss: 0.13489210605621338
# epoch: 9 batch: 28 current batch loss: 0.14134332537651062
# epoch: 9 batch: 29 current batch loss: 0.16512957215309143
# epoch: 10 batch: 0 current batch loss: 0.12081252038478851
# epoch: 10 batch: 1 current batch loss: 0.15995891392230988
# epoch: 10 batch: 2 current batch loss: 0.11728064715862274
# epoch: 10 batch: 3 current batch loss: 0.11633378267288208
# epoch: 10 batch: 4 current batch loss: 0.13302381336688995
# epoch: 10 batch: 5 current batch loss: 0.136539489030838
# epoch: 10 batch: 6 current batch loss: 0.1141194999217987
# epoch: 10 batch: 7 current batch loss: 0.1365411877632141
# epoch: 10 batch: 8 current batch loss: 0.15818066895008087
# epoch: 10 batch: 9 current batch loss: 0.15490473806858063
# epoch: 10 batch: 10 current batch loss: 0.15038590133190155
# epoch: 10 batch: 11 current batch loss: 0.15652643144130707
# epoch: 10 batch: 12 current batch loss: 0.12799154222011566
# epoch: 10 batch: 13 current batch loss: 0.13245125114917755
# epoch: 10 batch: 14 current batch loss: 0.112790048122406
# epoch: 10 batch: 15 current batch loss: 0.1360001415014267
# epoch: 10 batch: 16 current batch loss: 0.12511691451072693
# epoch: 10 batch: 17 current batch loss: 0.1314687281847
# epoch: 10 batch: 18 current batch loss: 0.1181410625576973
# epoch: 10 batch: 19 current batch loss: 0.12880606949329376
# epoch: 10 batch: 20 current batch loss: 0.12080129235982895
# epoch: 10 batch: 21 current batch loss: 0.13626772165298462
# epoch: 10 batch: 22 current batch loss: 0.1123589277267456
# epoch: 10 batch: 23 current batch loss: 0.11332453042268753
# epoch: 10 batch: 24 current batch loss: 0.12448359280824661
# epoch: 10 batch: 25 current batch loss: 0.1407124400138855
# epoch: 10 batch: 26 current batch loss: 0.12609454989433289
# epoch: 10 batch: 27 current batch loss: 0.12422610819339752
# epoch: 10 batch: 28 current batch loss: 0.12406844645738602
# epoch: 10 batch: 29 current batch loss: 0.1376481056213379
# epoch: 11 batch: 0 current batch loss: 0.12674406170845032
# epoch: 11 batch: 1 current batch loss: 0.10668089240789413
# epoch: 11 batch: 2 current batch loss: 0.13814032077789307
# epoch: 11 batch: 3 current batch loss: 0.1287669539451599
# epoch: 11 batch: 4 current batch loss: 0.119681715965271
# epoch: 11 batch: 5 current batch loss: 0.116985984146595
# epoch: 11 batch: 6 current batch loss: 0.11172546446323395
# epoch: 11 batch: 7 current batch loss: 0.13882772624492645
# epoch: 11 batch: 8 current batch loss: 0.14223384857177734
# epoch: 11 batch: 9 current batch loss: 0.10084452480077744
# epoch: 11 batch: 10 current batch loss: 0.12789957225322723
# epoch: 11 batch: 11 current batch loss: 0.11884945631027222
# epoch: 11 batch: 12 current batch loss: 0.13367818295955658
# epoch: 11 batch: 13 current batch loss: 0.1324671506881714
# epoch: 11 batch: 14 current batch loss: 0.12256811559200287
# epoch: 11 batch: 15 current batch loss: 0.10991676151752472
# epoch: 11 batch: 16 current batch loss: 0.13561518490314484
# epoch: 11 batch: 17 current batch loss: 0.12242809683084488
# epoch: 11 batch: 18 current batch loss: 0.12868379056453705
# epoch: 11 batch: 19 current batch loss: 0.11227557063102722
# epoch: 11 batch: 20 current batch loss: 0.10925126075744629
# epoch: 11 batch: 21 current batch loss: 0.14404572546482086
# epoch: 11 batch: 22 current batch loss: 0.11179065704345703
# epoch: 11 batch: 23 current batch loss: 0.12219807505607605
# epoch: 11 batch: 24 current batch loss: 0.12353108823299408
# epoch: 11 batch: 25 current batch loss: 0.13849514722824097
# epoch: 11 batch: 26 current batch loss: 0.11976489424705505
# epoch: 11 batch: 27 current batch loss: 0.12334049493074417
# epoch: 11 batch: 28 current batch loss: 0.12781956791877747
# epoch: 11 batch: 29 current batch loss: 0.0689942017197609
# epoch: 12 batch: 0 current batch loss: 0.12149783968925476
# epoch: 12 batch: 1 current batch loss: 0.1300218552350998
# epoch: 12 batch: 2 current batch loss: 0.1162610799074173
# epoch: 12 batch: 3 current batch loss: 0.116058848798275
# epoch: 12 batch: 4 current batch loss: 0.1287633180618286
# epoch: 12 batch: 5 current batch loss: 0.12277757376432419
# epoch: 12 batch: 6 current batch loss: 0.13139577209949493
# epoch: 12 batch: 7 current batch loss: 0.1158403754234314
# epoch: 12 batch: 8 current batch loss: 0.1238773912191391
# epoch: 12 batch: 9 current batch loss: 0.12258180975914001
# epoch: 12 batch: 10 current batch loss: 0.11654816567897797
# epoch: 12 batch: 11 current batch loss: 0.12166737020015717
# epoch: 12 batch: 12 current batch loss: 0.11693710088729858
# epoch: 12 batch: 13 current batch loss: 0.1143888458609581
# epoch: 12 batch: 14 current batch loss: 0.1255173683166504
# epoch: 12 batch: 15 current batch loss: 0.10554076731204987
# epoch: 12 batch: 16 current batch loss: 0.11008486896753311
# epoch: 12 batch: 17 current batch loss: 0.12229695916175842
# epoch: 12 batch: 18 current batch loss: 0.1129021942615509
# epoch: 12 batch: 19 current batch loss: 0.11523056775331497
# epoch: 12 batch: 20 current batch loss: 0.12415330111980438
# epoch: 12 batch: 21 current batch loss: 0.12592290341854095
# epoch: 12 batch: 22 current batch loss: 0.11670703440904617
# epoch: 12 batch: 23 current batch loss: 0.12396415323019028
# epoch: 12 batch: 24 current batch loss: 0.12171407788991928
# epoch: 12 batch: 25 current batch loss: 0.12562401592731476
# epoch: 12 batch: 26 current batch loss: 0.10295482724905014
# epoch: 12 batch: 27 current batch loss: 0.11748456954956055
# epoch: 12 batch: 28 current batch loss: 0.1203671395778656
# epoch: 12 batch: 29 current batch loss: 0.0963057354092598
# epoch: 13 batch: 0 current batch loss: 0.11472717672586441
# epoch: 13 batch: 1 current batch loss: 0.10536536574363708
# epoch: 13 batch: 2 current batch loss: 0.10835987329483032
# epoch: 13 batch: 3 current batch loss: 0.09209641814231873
# epoch: 13 batch: 4 current batch loss: 0.1201278418302536
# epoch: 13 batch: 5 current batch loss: 0.11177574843168259
# epoch: 13 batch: 6 current batch loss: 0.10940021276473999
# epoch: 13 batch: 7 current batch loss: 0.10647670179605484
# epoch: 13 batch: 8 current batch loss: 0.09989029914140701
# epoch: 13 batch: 9 current batch loss: 0.11229556798934937
# epoch: 13 batch: 10 current batch loss: 0.13304276764392853
# epoch: 13 batch: 11 current batch loss: 0.11967802792787552
# epoch: 13 batch: 12 current batch loss: 0.1205296441912651
# epoch: 13 batch: 13 current batch loss: 0.13190507888793945
# epoch: 13 batch: 14 current batch loss: 0.09627071022987366
# epoch: 13 batch: 15 current batch loss: 0.09421335160732269
# epoch: 13 batch: 16 current batch loss: 0.12094029784202576
# epoch: 13 batch: 17 current batch loss: 0.1000615730881691
# epoch: 13 batch: 18 current batch loss: 0.11527876555919647
# epoch: 13 batch: 19 current batch loss: 0.11786272376775742
# epoch: 13 batch: 20 current batch loss: 0.11053954809904099
# epoch: 13 batch: 21 current batch loss: 0.11414890736341476
# epoch: 13 batch: 22 current batch loss: 0.11222095787525177
# epoch: 13 batch: 23 current batch loss: 0.11581268161535263
# epoch: 13 batch: 24 current batch loss: 0.12070880830287933
# epoch: 13 batch: 25 current batch loss: 0.11842045187950134
# epoch: 13 batch: 26 current batch loss: 0.10425613075494766
# epoch: 13 batch: 27 current batch loss: 0.13016574084758759
# epoch: 13 batch: 28 current batch loss: 0.09117013216018677
# epoch: 13 batch: 29 current batch loss: 0.0798170194029808
# epoch: 14 batch: 0 current batch loss: 0.09203065186738968
# epoch: 14 batch: 1 current batch loss: 0.11984802782535553
# epoch: 14 batch: 2 current batch loss: 0.111155666410923
# epoch: 14 batch: 3 current batch loss: 0.10110455751419067
# epoch: 14 batch: 4 current batch loss: 0.10032118856906891
# epoch: 14 batch: 5 current batch loss: 0.1195962056517601
# epoch: 14 batch: 6 current batch loss: 0.09972986578941345
# epoch: 14 batch: 7 current batch loss: 0.1151101142168045
# epoch: 14 batch: 8 current batch loss: 0.09201555699110031
# epoch: 14 batch: 9 current batch loss: 0.12190251052379608
# epoch: 14 batch: 10 current batch loss: 0.09471888095140457
# epoch: 14 batch: 11 current batch loss: 0.10869680345058441
# epoch: 14 batch: 12 current batch loss: 0.10613426566123962
# epoch: 14 batch: 13 current batch loss: 0.10334153473377228
# epoch: 14 batch: 14 current batch loss: 0.0969146192073822
# epoch: 14 batch: 15 current batch loss: 0.11848632991313934
# epoch: 14 batch: 16 current batch loss: 0.10245376825332642
# epoch: 14 batch: 17 current batch loss: 0.11900457739830017
# epoch: 14 batch: 18 current batch loss: 0.09613287448883057
# epoch: 14 batch: 19 current batch loss: 0.10020258277654648
# epoch: 14 batch: 20 current batch loss: 0.11243551224470139
# epoch: 14 batch: 21 current batch loss: 0.12137331813573837
# epoch: 14 batch: 22 current batch loss: 0.09217961877584457
# epoch: 14 batch: 23 current batch loss: 0.11090253293514252
# epoch: 14 batch: 24 current batch loss: 0.08800999075174332
# epoch: 14 batch: 25 current batch loss: 0.11203940957784653
# epoch: 14 batch: 26 current batch loss: 0.11891372501850128
# epoch: 14 batch: 27 current batch loss: 0.09367097914218903
# epoch: 14 batch: 28 current batch loss: 0.114322230219841
# epoch: 14 batch: 29 current batch loss: 0.10983876138925552
# epoch: 15 batch: 0 current batch loss: 0.09549722075462341
# epoch: 15 batch: 1 current batch loss: 0.09183323383331299
# epoch: 15 batch: 2 current batch loss: 0.12195698916912079
# epoch: 15 batch: 3 current batch loss: 0.09856479614973068
# epoch: 15 batch: 4 current batch loss: 0.1307034194469452
# epoch: 15 batch: 5 current batch loss: 0.10426584631204605
# epoch: 15 batch: 6 current batch loss: 0.10096999257802963
# epoch: 15 batch: 7 current batch loss: 0.12337890267372131
# epoch: 15 batch: 8 current batch loss: 0.10736750066280365
# epoch: 15 batch: 9 current batch loss: 0.10319095849990845
# epoch: 15 batch: 10 current batch loss: 0.09542795270681381
# epoch: 15 batch: 11 current batch loss: 0.0848420187830925
# epoch: 15 batch: 12 current batch loss: 0.0964941754937172
# epoch: 15 batch: 13 current batch loss: 0.09115757048130035
# epoch: 15 batch: 14 current batch loss: 0.1004389300942421
# epoch: 15 batch: 15 current batch loss: 0.09781196713447571
# epoch: 15 batch: 16 current batch loss: 0.10557135194540024
# epoch: 15 batch: 17 current batch loss: 0.1078004240989685
# epoch: 15 batch: 18 current batch loss: 0.11926060169935226
# epoch: 15 batch: 19 current batch loss: 0.09054603427648544
# epoch: 15 batch: 20 current batch loss: 0.11485135555267334
# epoch: 15 batch: 21 current batch loss: 0.08955378830432892
# epoch: 15 batch: 22 current batch loss: 0.09973321855068207
# epoch: 15 batch: 23 current batch loss: 0.08174679428339005
# epoch: 15 batch: 24 current batch loss: 0.09748172760009766
# epoch: 15 batch: 25 current batch loss: 0.10610484331846237
# epoch: 15 batch: 26 current batch loss: 0.09417415410280228
# epoch: 15 batch: 27 current batch loss: 0.07826471328735352
# epoch: 15 batch: 28 current batch loss: 0.0891362875699997
# epoch: 15 batch: 29 current batch loss: 0.06238902360200882

# %% [markdown]
# # Testing
# ----------------------

# %%
good = 0
wrong = 0

net.eval()              #it notifies the network layers (especially batchnorm or dropout layers, which we don't use in this example) that we are doing evaluation
with torch.no_grad():   #it prevents that the net learns during evalution. The gradients are not computed, so this makes it faster, too
    for batch, data in enumerate(testloader): #batches in test are of size 1
        datapoint, label = data

        prediction = net(datapoint.to(device))                  #prediction has values representing the "prevalence" of the corresponding class
        classification = torch.argmax(prediction)    #the class is the index of maximal "prevalence"

        if classification.item() == label.item():
            good += 1
        else:
            wrong += 1

print("accuracy = ", good/(good+wrong))
# Out:
# accuracy =  0.9809

# %% [markdown]
# # Understanding Kernel Size, Stride and Padding

# %% [markdown]
# ## Task: Designing a Convolutional Neural Network with a Target Receptive Field
#
# Design a convolutional neural network using only 3×3 or 5×5 convolutional layers and 2×2 max-pooling layers without overlap (i.e., with stride 2). Use no padding in any layer. Insert a max-pooling layer after every two or three convolutional layers.
#
# Your goal is to construct an architecture such that the receptive field of each output neuron is approximately 60×60 pixels.
#
# Compute the receptive field size of the final output layer.
#
# Compute the effective stride of the output layer with respect to the input.
#
# Assuming an input image size of 400×400, determine the spatial size of the output feature map.
#
# Q: Where would you locate ReLU layers?
# Q: What if we can't match the desired input size with our architecture?
# Q: Discuss what possible impact padding can have on the network performance.

# %% [markdown]
# # **Homework Assignment – Adversarial Examples**
#
# In this assignment, you will explore how small (invisible to humans) changes to real digits can _fool_ the CNN into misclassifying them, even though the changes are imperceptible to humans.
#
#
#
# ## Task 1 – CNN Dreams: Last Homework Assignment Revisited
#
# Re-run the input optimization process (for NN dreams) from the previous MLP-class homework assignment, but this time using the **LeNet-5 CNN model** we trained in this class.
#
#
# 1. Starting from ten random noise images, optimize the input so that each image is classified with high confidence as one of the digits 0 through 9.
# 2. Include an **L2 penalty** on the input to keep the images visually closer to realistic digits. Use a range of penalty strengths (e.g., $\lambda_{l2}$ = 0, and then 0.01 through 10.0).
# 3. Compare the generated images (with and without L2 penalty) to those generated by the MLP:
#    - Are they more or less readable?
#    - Do they resemble real MNIST digits more closely or less?
#    - Why do you think that happens? Consider the CNN’s inductive biases and architectural properties.
#
# Use `cross_entropy_loss + lambda_l2 * input.pow(2).mean()` as your objective.
#
# Reuse your code: visualize confidence evolution during optimization and generate image grids and (optionally) animations showing how the inputs evolve.
#
#
# ## Task 2 – Adversarial Examples: Fooling LeNet-5
#
# This is the core focus of the assignment.
#
# Using a batch of **real MNIST digits** (e.g., nine examples per class), craft **adversarial examples** by adding subtle, trained noise to the input images. Your goal is to:
#
# - **Keep the human-perceived digit the same** (e.g., a "7" should still look like a "7"),
# - But **cause LeNet-5 to misclassify it** – as every other class different from the original, hence nine examples per class.
#
# ### Objective
# For each image $x$ and its true label $y$, learn a perturbation $\delta$ such that:
#
# - $\text{LeNet5}(x + \delta) = y_{\text{wrong}} $,
# - and $ \|\delta\|_2 $ is as small as possible (penalize large perturbations), to keep $x + \delta$ *look* like $x$ for humans.
#
# ### Optimization
# Use gradient-based optimization on $\delta$ (the noise), while keeping the network weights frozen. Your loss might look like:
#
# ```
# loss = cross_entropy(model(x + delta), target_wrong_class) +
#        lambda_l2 * delta.pow(2).mean()
# ```
#
# Tune the $\lambda_{l2}$ to find the best range.
#
# ### Deliverables for the Second Task
# - Select some best examples, showing the original digit and its (correct) classification and the perturbed digit (hopefully, still looking the same to humans) and how it gets misclassified. Show them side by side.
# - Report:
#   - Success rate of attacks (it doesn't need to be very formal),
#   - Effect of $\lambda_{l2}$ on visibility of the noise and success of misclassification,
#   - Example image grids and confidence plots.
#
#
#
# ## Deliverables for the Homework Assignment
# - A Google Colab notebook with:
#   - Complete implementation for both tasks.
#   - Visualizations and animations (animations are optional but encouraged).
#   - Clear written analysis of your findings.
# - Upload the notebook and results to your GitHub repository for the course.
# - Include a link to the notebook and video (if applicable) in the `README.md`.
# - In the notebook, include “Open in Colab” badge so it can be launched directly.
